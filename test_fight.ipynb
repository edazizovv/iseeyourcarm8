# %%
# _old

# %%
import os
from imageai.Detection import ObjectDetection
# Out:
# Using TensorFlow backend.

# %%
from utils import catch_the_car
from worker import Worker
# Out:
# WARNING:tensorflow:From c:\sygm\ramp\ip-02\ostrta\nomeroff-net\NomeroffNet\Detector.py:14: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\sygm\ramp\ip-02\ostrta\nomeroff-net\NomeroffNet\Detector.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
# specifications

# %%
source = './test_fight'
detected = source + '/detected'
cropped = source + './cropped'
image0 = '/60.jpg'
image1 = '/61.jpg'
new_env = 'E:/penv/iseeyourcarm8_new/Scripts/python.exe'

# %%
# car-detector

# %%
model_path = './models'

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(model_path, "yolo.h5"))
detector.loadModel()

custom = detector.CustomObjects(car=True, motorcycle=True, bus=True, truck=True)
# Out:
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
# bork

# %%
NOMEROFF_NET_DIR = os.path.abspath('./')

MASK_RCNN_DIR = os.path.join(NOMEROFF_NET_DIR, 'Mask_RCNN')
MASK_RCNN_LOG_DIR = os.path.join(NOMEROFF_NET_DIR, 'logs')

bork = Worker(NOMEROFF_NET_DIR, MASK_RCNN_DIR, MASK_RCNN_LOG_DIR, 
              load_model="latest", options_detector="latest", text_detector_module="eu", load_text_detector="latest")
# Out:
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\mrcnn\model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\mrcnn\model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From e:\penv\iseeyourcarm8_old\lib\site-packages\mrcnn\model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# ...

# %%
# im0

# %%
prev0 = None
result0 = catch_the_car(bork, detector, custom, 
                        input_image_path=(source + image0), 
                        output_detected_image_path=(detected + image0), output_cropped_image_path=(cropped + image0), 
                        comparator_env=new_env, probability_threshold=30, prev=prev0)
# Out:
# c:\sygm\ramp\ip-02\ostrta\nomeroff-net\NomeroffNet\RectDetector.py:270: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array([arrA0,arrB0,arrA1,arrB1])
# [8.8353197e-05 7.6470904e-05 9.9978191e-01 5.3249991e-05]

# %%
result0
# Out:
# (<PIL.Image.Image image mode=RGB size=833x535 at 0x2170F7977C8>,
#  'AA0055BP',
#  nan,
#  nan)

# %%
result0[0]
# Out:
# <PIL.Image.Image image mode=RGB size=833x535 at 0x2170F7977C8>

# %%
# im1

# %%
prev1 = {'im': (cropped + image0), 
         'nc': result0[1],
         'im_c': 'deepai',
         'nc_c': 'damerau_levenshtein'}
result1 = catch_the_car(bork, detector, custom, 
                        input_image_path=(source + image1), 
                        output_detected_image_path=(detected + image1), output_cropped_image_path=(cropped + image1), 
                        comparator_env=new_env, probability_threshold=30, prev=prev1)
# Out:
# [8.5235893e-05 7.7741650e-05 9.9978322e-01 5.3921704e-05]

# %%
result1
# Out:
# (<PIL.Image.Image image mode=RGB size=726x501 at 0x21710DA3548>,
#  'AA0055BP',
#  22.0,
#  0.0)

# %%
result1[0]
# Out:
# <PIL.Image.Image image mode=RGB size=726x501 at 0x21710DA3548>
